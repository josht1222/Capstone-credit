# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np
import warnings

# %%
credit_card = pd.read_csv('creditcard.csv')

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card.shape
# Out:
# (284807, 31)

# %%
#284807 rows, 31 columns

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
#Seems to have no null values because each column has the maximum # of non_null values given the shape
#Don't need to worry about filling, dropping, or replacing any of those values

# %%
#Find the percentage share of class values, either 0 or 1.
classes_count = credit_card['Class'].value_counts()
nonfraud_share = (classes_count[0]/credit_card['Class'].count()*100)
nonfraud_share
# Out:
# 99.82725143693798

# %%
#99.83% of transactions are not fraudulent
#Which means 0.17% of transactions are fraudulent.

# %%
#creating a correlation heatmap to see what variables have the highest correlation to each other
sns.heatmap(credit_card.corr())
plt.show()

# %%
#Looks like no meaningful relationships exist within the heatmap

# %%
sns.countplot(x = 'Class', data = credit_card)
plt.show()

# %%
plt.scatter(credit_card['Amount'], credit_card['Class'])
plt.xlabel('$ amount for transaction')
plt.ylabel('Time elapsed since first transaction (seconds)')
plt.show()

# %%
plt.boxplot(credit_card['Amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16a620ad0>,
#   <matplotlib.lines.Line2D at 0x16a621690>],
#  'caps': [<matplotlib.lines.Line2D at 0x16a622250>,
#   <matplotlib.lines.Line2D at 0x16a622cd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16a4d3210>],
#  'medians': [<matplotlib.lines.Line2D at 0x16a623750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16a62c1d0>],
#  'means': []}

# %%
#credit_card is our dataset

# %%
#Create 2 new datasets one that represents

# %%
non_fraud_trans = credit_card[credit_card['Class']== 0]
non_fraud_trans.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
non_fraud_trans.shape
# Out:
# (284315, 31)

# %%
fraud_trans = credit_card[credit_card['Class']==1]
fraud_trans.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
print(fraud_trans.shape)
# Out:
# (492, 31)

# %%
credit_card.shape
# Out:
# (284807, 31)

# %%
#Our dataset contains 31 columns, 284,807 transactions, 
# 284,315 of those transactions were deemed non-fraudulent
# 492 transactions deemed fraudulent.

# %%
credit_card['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
plt.boxplot(credit_card['Amount'])
plt.show()

# %%
# the boxplot above ^, shows that amount (one of our few variables that has a large std & range)
#Has many outliers so we should probably standardize & transform this variable

# %%
credit_card['Time'].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %%
plt.boxplot(credit_card['Time'])
plt.show()

# %%
#The boxplot above ^, shows that 'Time' (One of the possible 2 variables that has a large range and std)
#Though the boxplot shows that there are no outliers (everything falls within the threshold)
#No need to standardize this variable.
#Since most of our dataset is mostly V1-V28 (varaibles we have little knowledge in) 
#we will continue to use 'Time' in our model.

# %%
#For our model, I believe with an imbalanced dataset that is going to predict the fraudulent activity in card transaction
#Would be a KNN (K-Neighbors) model, using a classification method to best predict
#Alternative method would be random forest classifier, we will make and test both.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
#Data Visualization:

# %%
plt.scatter(credit_card['Time'], credit_card['Amount'], c = credit_card['Class'], alpha = 0.1)
plt.show()

# %%
plt.hist(non_fraud_trans['Amount'], bins = 5)
plt.show()

# %%
plt.hist(fraud_trans['Amount'], bins = 5)
# Out:
# (array([450.,  31.,   4.,   5.,   2.]),
#  array([   0.   ,  425.174,  850.348, 1275.522, 1700.696, 2125.87 ]),
#  <BarContainer object of 5 artists>)

# %%
non_fraud_trans['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_trans['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
bins = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]

# %%
plt.hist(non_fraud_trans['Amount'], bins = bins)
# Out:
# (array([2.74858e+05, 6.39700e+03, 1.71300e+03, 6.57000e+02, 2.41000e+02,
#         1.60000e+02, 9.40000e+01, 7.20000e+01, 4.50000e+01, 2.30000e+01]),
#  array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500., 4000.,
#         4500., 5000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(fraud_trans['Amount'], bins = bins)
# Out:
# (array([457.,  26.,   6.,   2.,   1.,   0.,   0.,   0.,   0.,   0.]),
#  array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500., 4000.,
#         4500., 5000.]),
#  <BarContainer object of 10 artists>)

# %%
# 'Amount' is not a big indicator for if a transaction is not a great indicator if a transaction is fraudulent or not
#Although fraudulent transactions have a slightly heigher mean, could be due to a smaller sample size ^^

# %%
#Now to do the same thing with times

# %%
plt.hist(non_fraud_trans['Time'], bins = 10)
# Out:
# (array([10468., 16907., 38447., 38487., 40194., 10077., 17150., 38917.,
#         40713., 32955.]),
#  array([     0. ,  17279.2,  34558.4,  51837.6,  69116.8,  86396. ,
#         103675.2, 120954.4, 138233.6, 155512.8, 172792. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(fraud_trans['Time'], bins = 10)
# Out:
# (array([42., 47., 80., 63., 44., 63., 21., 33., 56., 43.]),
#  array([   406. ,  17400.2,  34394.4,  51388.6,  68382.8,  85377. ,
#         102371.2, 119365.4, 136359.6, 153353.8, 170348. ]),
#  <BarContainer object of 10 artists>)

# %%
# 'Time' is pretty similar to 'Amount' in that it doesn't show much compared between 'Class'
#Although it does seem that fraudulent transactions take a little less time compared to non-fraud

# %%
non_fraud_trans['Time'].describe()
# Out:
# count    284315.000000
# mean      94838.202258
# std       47484.015786
# min           0.000000
# 25%       54230.000000
# 50%       84711.000000
# 75%      139333.000000
# max      172792.000000
# Name: Time, dtype: float64

# %%
fraud_trans['Time'].describe()
# Out:
# count       492.000000
# mean      80746.806911
# std       47835.365138
# min         406.000000
# 25%       41241.500000
# 50%       75568.500000
# 75%      128483.000000
# max      170348.000000
# Name: Time, dtype: float64

# %%
#There is a very similar std, but 'Time's mean for fraudulent transactions is slightly lower than non-fraud
#Therefore 'Time' and 'Amount' should be included in the model
#Although, only slightly differ between fraudulent and non-fraud

# %%
#PART 4: MODEL BUILDING FOR CLASSIFICATION OF CREDIT CARD TRANSACTIONS

# %%
#We will try multiple different models, mostly focusing on random forests and KNN

# %%
#scaler is gonna be used to standardize our amount column after we train/test this dataset.
